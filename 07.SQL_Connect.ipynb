# %%
from db_info import user, password, host, port, database
import pandas as pd
import mysql.connector

db_connection = mysql.connector.connect(
user = user,
password = password,
host = host,
port = port,
database = database,
)

cursor = db_connection.cursor()

cursor.execute("select * from injury_content")

result = cursor.fetchall()

df = pd.DataFrame(result, columns = [i[0] for i in cursor.description])

df
# Out:
#       판례정보일련번호                 사건번호  선고          판결유형  \
# 0       241209           2022두51031  선고            판결
# 1       240925           2023도18812  선고            판결
# 2       240809            2021도6357  선고      전원합의체 판결
# 3       239933           2023도11371  선고            판결
# 4       241179           2023도12851  선고            판결
# ...        ...                  ...  ..           ...
# 4184    133679  4288형공837의2,4289형공2  선고  제1형사부판결 : 확정
# 4185     86201            4288형상308  선고            판결
# 4186     86162            4288형상315  선고            판결
# 4187    215351            4287형상189  선고            판결
# 4188     85842              4284형상1  선고            판결
#
#                                                    판시사항  \
# 0      [1] 국내사업장을 가진 외국법인이 국내 및 국외에 걸쳐 선박에 의한 국제운송업을...
# 1       특수상해죄 및 특수협박죄의 구성요건 중 위험한 물건을 ‘휴대하여’의 의미 / 이...
# 2     형사소송법 제33조 제1항 제1호에서 필요적 국선변호인 선정사유 중 하나로 정한 ‘...
# 3       [1] 법원이 피해자 등을 공판기일에 출석하게 하여 형사소송법 제294조의2 제...
# ...

# %%
cursor.execute("select * from injury_list")

result = cursor.fetchall()

df = pd.DataFrame(result, columns = [i[0] for i in cursor.description])

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cursor.execute("select * from injury_list")
#       3 result = cursor.fetchall()
#       5 df = pd.DataFrame(result, columns = [i[0] for i in cursor.description])
#
# NameError: name 'cursor' is not defined

# %%
cursor.execute("select * from injury_list il inner join injury_content ic on il.판례일련번호=ic.판례정보일련번호 where ic.판결유형='판결'")

result = cursor.fetchall()

df = pd.DataFrame(result, columns = [i[0] for i in cursor.description])

df
# Out:
#       판례일련번호                                                사건명        사건번호  \
# 0     241209  법인세등부과처분취소[국내사업장을 가진 외국법인이 국내 및 국외에 걸쳐 선박에 의한 ...  2022두51031
# 1     240925  폭행·특수상해(인정된죄명:상해)·특수협박(인정된죄명:협박)·감금[피고인이 위험한 물...  2023도18812
# 2     239933                                     상해(인정된죄명:강간상해)  2023도11371
# 3     241179                                    강도상해·감금·폭행·강요미수  2023도12851
# 4     240893       살인·상해·마약류관리에관한법률위반(마약)·마약류관리에관한법률위반(향정)·부착명령  2023도11559
# ...      ...                                                ...         ...
# 2974  154966                                              독직폭행등       69도43
# 2975  154985                                     폭력행위등처벌에관한법률위반     70도2109
# 2976  155094                                                살인등      70도923
# 2977  153396                                              손해배상등      67다105
# 2978  150444                                               손해배상  4294민상1355
#
#             선고일자  법원명 사건종류명  \
# ...

# %%
cursor.description
# Out:
# [('Tables_in_nof', 253, None, None, None, None, 1, 0, 255)]
