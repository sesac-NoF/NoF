# %%
import pandas as pd

# %%
a = pd.read_csv('data/lawSearch_jh.csv')
a
# Out:
#        판례일련번호                       사건명       사건번호        선고일자     법원명 사건종류명  \
# 0      101264            재심청구기각결정에대한재항고      85모32  1985.09.28     대법원    형사
# 1       76281  보건범죄단속에관한특별조치법위반(식품)피고사건    85고합228  1985.09.27  인천지방법원    형사
# 2       76242                 건물철거등청구사건    84나2318  1985.09.27  서울고등법원    민사
# 3       76243                  손해배상청구사건    84나4640  1985.09.27  서울고등법원    민사
# 4      224051                해고무효확인청구소송     85나625  1985.09.27  서울고등법원    민사
# ...       ...                       ...        ...         ...     ...   ...
# 20073   85831                  토지건물이전등기  4280민상383  1948.05.27     대법원    민사
# 20074   85836                 토지소유권이전등기  4281민상417  1948.04.12     대법원    민사
# 20075   85835                부동산소유권이전등기  4281민상362  1948.04.07     대법원    민사
# 20076   85834               토지건물소유권이전등기  4281민상298  1948.04.02     대법원    민사
# 20077   85830                토지건물매매무효확인  4280민상278  1947.03.23     대법원    민사
#
# ...

# %%
#판례목록 total 만들기
law_search_filse = ['data/lawSearch_jh.csv','data/lawSearch_js.csv','data/lawSearch_yk2.csv','data/lawSearch_dh.csv']

total_search_dfs = [pd.read_csv(file) for file in law_search_filse]

# %%
total_search_dfs[2]
# Out:
#        판례일련번호                사건명        사건번호        선고일자     법원명 사건종류명  \
# 0      147393          소유권보존등기말소  2008다71575  2010.12.09     대법원    민사
# 1      147384            상속세경정청구  2008두10133  2010.12.09     대법원    세무
# 2      150031  횡령(인정된죄명:점유이탈물횡령)    2010도891  2010.12.09     대법원    형사
# 3      188185             통보처분취소  2010누12639  2010.12.08  서울고등법원  일반행정
# 4      160470              배당 이의  2010가합8730  2010.12.08  창원지방법원    민사
# ...       ...                ...         ...         ...     ...   ...
# 22495  116599              업무상횡령      98도292  1998.04.14     대법원    형사
# 22496  196352            소유권이전등기    96다47104  1998.04.14     대법원    민사
# 22497  196358   개인택시운송사업면허제외처분취소      98두984  1998.04.14     대법원  일반행정
# 22498  196355                관리비    97다50114  1998.04.14     대법원    민사
# 22499  196348            손해배상(기)    95다15032  1998.04.14     대법원    민사
#
#                                                   판례상세링크
# 0      /DRF/lawService.do?OC=ykdb0508&target=prec&ID=...
# ...

# %%
combined_df = pd.concat(total_search_dfs, ignore_index=True)
print(combined_df)
# Out:
#        판례일련번호                                                사건명        사건번호  \
# 0      101264                                     재심청구기각결정에대한재항고       85모32
# 1       76281                           보건범죄단속에관한특별조치법위반(식품)피고사건     85고합228
# 2       76242                                          건물철거등청구사건     84나2318
# 3       76243                                           손해배상청구사건     84나4640
# 4      224051                                         해고무효확인청구소송      85나625
# ...       ...                                                ...         ...
# 87573  150030                                               분양대금  2009다75321
# 87574  147374                                            채무부존재확인  2010다70773
# 87575  150051                                              부당이득금  2010다62413
# 87576  149558                                            거절결정(상)   2010허7198
# 87577  147367  특정경제범죄가중처벌등에관한법률위반(횡령)[피고인4,5,6,7,8,9,11,13,14...  2010도11015
#
#              선고일자     법원명 사건종류명  \
# ...

# %%
combined_df.to_csv('data/lawSearch_total.csv', index=False)

# %%
combined_df['판례일련번호'].duplicated().value_counts()
# Out:
# 판례일련번호
# False    87578
# Name: count, dtype: int64
