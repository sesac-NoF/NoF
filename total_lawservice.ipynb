# %%
import pandas as pd

# %%
total_search = pd.read_csv('data/lawSearch_total.csv')

# %%
law_service_filse = ['data/lawService_jh.csv','data/lawService_js.csv','data/lawService_yk.csv','data/lawService_dh2.csv']

total_service_dfs = [pd.read_csv(file) for file in law_service_filse]

# %%
total_service_dfs[1]
# Out:
#        판례정보일련번호     사건번호  선고          판결유형  \
# 0        116601   98도364  선고            판결
# 1        116564  98다6565  선고            판결
# 2        196350  96다8826  선고            판결
# 3        116597   98도150  선고            판결
# 4        116598   98도231  선고            판결
# ...         ...      ...  ..           ...
# 22495    100987  85도1146  선고            판결
# 22496    100978   85누529  선고            판결
# 22497    100995  85도1721  선고            판결
# 22498    205858   85마410   자            결정
# 22499     76371  84구1046  선고  제2특별부판결 : 확정
#
#                                                     판시사항  \
# 0      도시계획법 제90조 제2호, 제21조 제2항 소정의 '토지형질변경'의 개념 및 토지...
# 1      리스물건이 공급되었으나 이용자가 정당한 사유 없이 물건수령증을 교부하지 않고 있다는...
# 2      [1] 영업양도의 의미와 그 판단 기준<br/>[2] 상법 제42조 제1항 소정의 ...
# 3      공무소에 신고한 허위사실이 친고죄로서 그에 대한 고소기간이 경과한 것이 신고내용 자...
# 4      [1] 고지의무위반과 사기죄의 성부<br/>[2] 중고 자동차 매매에 있어서 매도인...
# ...                                                  ...
# ...

# %%
combined_df = pd.concat(total_service_dfs, ignore_index=True)
print(combined_df)
# Out:
#        판례정보일련번호        사건번호  선고           판결유형  \
# 0        101264       85모32   자             결정
# 1         76281     85고합228  선고   제2형사부판결 : 항소
# 2         76242     84나2318  선고  제10민사부판결 : 상고
# 3         76243     84나4640  선고  제10민사부판결 : 확정
# 4        224051      85나625  선고  제12민사부판결 : 상고
# ...         ...         ...  ..            ...
# 87573    150030  2009다75321  선고             판결
# 87574    147374  2010다70773  선고             판결
# 87575    150051  2010다62413  선고             판결
# 87576    149558   2010허7198  선고             판결
# 87577    147367  2010도11015  선고             판결
#
#                                                     판시사항  \
# 0      형사소송법 제420조 제5호 소정의 "명백한 증거가 새로 발견된 때"의 의미\r\n...
# 1           무허가 유지제조영업이 죄가 되는 것을 모른 경우 법률의 착오에 해당여부<br/>
# 2      주위적 청구를 인용한 판결에 대하여 피고가 항소를 한 경우, 예비적 청구의 이심여부...
# 3               운전사의 과실로 차량을 도난당한 경우의 차량보유자의 운행지배여부<br/>
# 4       해고권을 유보하는 시용기간을 두기로 한 고용계약에 있어서의 해고와 정당한 사유<br/>
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87578 entries, 0 to 87577
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   판례정보일련번호  87578 non-null  int64
#  1   사건번호      87551 non-null  object
#  2   선고        87550 non-null  object
#  3   판결유형      87551 non-null  object
#  4   판시사항      73323 non-null  object
#  5   판결요지      63756 non-null  object
#  6   참조조문      72148 non-null  object
#  7   참조판례      40869 non-null  object
#  8   판례내용      87551 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 6.0+ MB

# %%
combined_df.isnull().sum()
# Out:
# 판례정보일련번호        0
# 사건번호           27
# 선고             28
# 판결유형           27
# 판시사항        14255
# 판결요지        23822
# 참조조문        15430
# 참조판례        46709
# 판례내용           27
# dtype: int64

# %%
# 사건번호가 없는것들 확인
combined_df[combined_df['사건번호'].isnull()==True]
# 아예 정보가없는 데이터
# total_search 확인 후 결측치 처리 -> 삭제
# Out:
#        판례정보일련번호 사건번호   선고 판결유형 판시사항 판결요지 참조조문 참조판례 판례내용
# 76197    184023  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 76359    194843  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 77387    220209  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 77594    181024  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 77738    179265  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 77949    193287  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78260    178135  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78458    182244  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78494    202134  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78641    177618  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78747    188223  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78792    177559  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78916    182664  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78929    192709  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 79263    194854  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 79437    182207  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
# 선고가없는것 확인
combined_df[combined_df['선고'].isnull()==True]
# Out:
#        판례정보일련번호         사건번호   선고 판결유형 판시사항 판결요지 참조조문 참조판례  \
# 69630    217517  2019느단10098  NaN   심판  NaN  NaN  NaN  NaN
# 76197    184023          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 76359    194843          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 77387    220209          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 77594    181024          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 77738    179265          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 77949    193287          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78260    178135          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78458    182244          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78494    202134          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78641    177618          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78747    188223          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78792    177559          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78916    182664          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 78929    192709          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
combined_df[combined_df['판례정보일련번호']==184023]
# Out:
#        판례정보일련번호 사건번호   선고 판결유형 판시사항 판결요지 참조조문 참조판례 판례내용
# 76197    184023  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
clean_combined = combined_df.dropna(subset=['사건번호'])
clean_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87551 entries, 0 to 87577
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   판례정보일련번호  87551 non-null  int64
#  1   사건번호      87551 non-null  object
#  2   선고        87550 non-null  object
#  3   판결유형      87551 non-null  object
#  4   판시사항      73323 non-null  object
#  5   판결요지      63756 non-null  object
#  6   참조조문      72148 non-null  object
#  7   참조판례      40869 non-null  object
#  8   판례내용      87551 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 6.7+ MB

# %%
clean_combined.isnull().sum()
# Out:
# 판례정보일련번호        0
# 사건번호            0
# 선고              1
# 판결유형            0
# 판시사항        14228
# 판결요지        23795
# 참조조문        15403
# 참조판례        46682
# 판례내용            0
# dtype: int64

# %%
len(clean_combined)
# Out:
# 87551
