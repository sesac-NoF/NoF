# %% [markdown]
# # 데이터베이스에 저장되어있는 데이터 불러오기

# %% [markdown]
# ```
# pip install mysql-connector-python
#
# 먼저 설치필요
# ```

# %%
import mysql.connector
import pandas as pd
from db_info import user,password,host,database,port

db_connection = mysql.connector.connect(
    host = host,
    user = user,
    password = password,
    database = database,
    port = port
)

cursor = db_connection.cursor()

cursor.execute("SELECT * FROM law_list")

result = cursor.fetchall()

df = pd.DataFrame(result, columns = [i[0] for i in cursor.description])

df
# Out:
#       법령일련번호 현행연혁코드                                     법령명한글         법령약칭명  \
# 0     253527     현행                10ㆍ27법난 피해자의 명예회복 등에 관한 법률      10ㆍ27법난법
# 1     264477     현행            10ㆍ27법난 피해자의 명예회복 등에 관한 법률 시행령  10ㆍ27법난법 시행령
# 2     262693     현행  10ㆍ29이태원참사 피해자 권리보장과 진상규명 및 재발방지를 위한 특별법          None
# 3     257787     현행                     112신고의 운영 및 처리에 관한 법률      112신고처리법
# 4     263521     현행                 112신고의 운영 및 처리에 관한 법률 시행령  112신고처리법 시행령
# ...      ...    ...                                       ...           ...
# 5402  263069     현행                         후천성면역결핍증 예방법 시행규칙   에이즈예방법 시행규칙
# 5403  132607     현행                      휴직법관에 대한 보수지급에 관한 규칙          None
# 5404  257349     현행                                   희귀질환관리법          None
# 5405  258803     현행                               희귀질환관리법 시행령          None
# 5406  256913     현행                              희귀질환관리법 시행규칙          None
#
#        법령ID      공포일자   공포번호 제개정구분명           소관부처코드        소관부처명   법령구분명  \
# 0     10719  20230808  19592   타법개정          1371000      문화체육관광부      법률
# 1     10831  20240730  34785   타법개정          1371000      문화체육관광부    대통령령
# 2     14656  20240521  20427     제정          1741000        행정안전부      법률
# 3     14565  20240102  19870     제정          1320000          경찰청      법률
# 4     14679  20240702  34629     제정          1320000          경찰청    대통령령
# ...     ...       ...    ...    ...              ...          ...     ...
# 5402   8764  20240530   1014   일부개정          1790387        질병관리청  보건복지부령
# 5403   6002  20130218   2451   일부개정          9740000          대법원   대법원규칙
# 5404  12443  20231226  19844   일부개정  1352000,1790387  보건복지부,질병관리청      법률
# 5405  12746  20240116  34147   일부개정  1352000,1790387  보건복지부,질병관리청    대통령령
# 5406  12776  20231214    984   일부개정  1352000,1790387  보건복지부,질병관리청  보건복지부령
#
#           시행일자                                             볍령상세링크
# 0     20230808  /DRF/lawService.do?OC=younwjdtjr&target=law&MS...
# 1     20240730  /DRF/lawService.do?OC=younwjdtjr&target=law&MS...
# 2     20240521  /DRF/lawService.do?OC=younwjdtjr&target=law&MS...
# 3     20240703  /DRF/lawService.do?OC=younwjdtjr&target=law&MS...
# 4     20240703  /DRF/lawService.do?OC=younwjdtjr&target=law&MS...
# ...        ...                                                ...
# 5402  20240530  /DRF/lawService.do?OC=younwjdtjr&target=law&MS...
# 5403  20130218  /DRF/lawService.do?OC=younwjdtjr&target=law&MS...
# 5404  20231226  /DRF/lawService.do?OC=younwjdtjr&target=law&MS...
# 5405  20240116  /DRF/lawService.do?OC=younwjdtjr&target=law&MS...
# 5406  20231214  /DRF/lawService.do?OC=younwjdtjr&target=law&MS...
#
# [5407 rows x 13 columns]
