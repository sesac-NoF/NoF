# %%
import pandas as pd

a = pd.read_csv('data/상해_본문2.csv')

a[a['판례내용'].str.len() >= 65536]
# Out:
#       판례정보일련번호                                               사건번호  선고  \
# 16      238571                                        2022노310주1)  선고
# 134     209175                                          2015도6809  선고
# 155     182110                                           2014노490  선고
# 168     182098                            2014고합180,2014고합384(병합)  선고
# 289     221231                              2011고합4,13(병합),38(병합)  선고
# 1194    226005                         2015가합579799, 2016가합526204  선고
# 1212    225515                                           2019노119  선고
# 1242    217621                                          2018고합823  선고
# 1403    193041              2016고합12, 2016고합46(병합), 2016고합102(병합)  선고
# 1426    224313                                 2015고합690, 728(병합)  선고
# 1472    209408                                           2015노800  선고
# 1487    209161                                         2014도10978  선고
# ...

# %%
# 문자열 길이 계산
a['길이'] = a['판례내용'].str.len()

# 가장 긴 문자열 찾기
가장_긴_판례 = a.loc[a['길이'].idxmax()]

# 결과 출력
print(가장_긴_판례)
# Out:
# 판례정보일련번호                                               178238
# 사건번호                        2013고합620,624(병합),699(병합),851(병합)
# 선고                                                         선고
# 판결유형                                                       판결
# 판시사항                                                      NaN
# 판결요지                                                      NaN
# 참조조문                                                      NaN
# 참조판례                                                      NaN
# 판례내용        【피 고 인】 <br/>【검    사】 최태원, 김훈영(기소, 공판), 정재욱, 양...
# 길이                                                     300787
# Name: 1553, dtype: object

# %%
# %pip install pymysql sqlalchemy
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.dialects.mysql import LONGTEXT,TEXT
from db_info import user, password, host, port, database
dtype = {
    '판례내용' : LONGTEXT,
    '판시사항': TEXT,
    '판결요지': TEXT,
    '참조조문': TEXT,
    '참조판례': TEXT,
}

# CSV 파일 불러오기
df = pd.read_csv('data/상해_본문2.csv')

# MySQL 연결 (사용자 이름, 비밀번호, 호스트 및 데이터베이스 이름을 설정)
username = user
password = password
host = host
database = database
port = port
\
# SQLAlchemy 엔진 생성
engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")
# 테이블로 데이터 저장
df.to_sql('injury_content', con=engine, if_exists='replace', index=False, dtype=dtype)

print("데이터가 성공적으로 MySQL로 저장되었습니다.")
# Out:
# dddd
# 데이터가 성공적으로 MySQL로 저장되었습니다.
