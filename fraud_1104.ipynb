# %%
import pandas as pd
import string

df = pd.read_csv('data/df_fraud_keyword.csv', index_col=False)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4182 entries, 0 to 4181
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   판례일련번호         4182 non-null   int64
#  1   사건명            4180 non-null   object
#  2   사건번호           4182 non-null   object
#  3   선고일자           4182 non-null   object
#  4   법원명            4182 non-null   object
#  5   사건종류명          4182 non-null   object
#  6   판례상세링크         4182 non-null   object
#  7   판례정보일련번호       4182 non-null   int64
#  8   선고             4182 non-null   object
#  9   판결유형           4182 non-null   object
#  10  판시사항           3028 non-null   object
#  11  판결요지           2482 non-null   object
#  12  참조조문           3001 non-null   object
#  13  참조판례           1808 non-null   object
#  14  판례내용           4182 non-null   object
#  15  판례내용_상단        4182 non-null   object
#  16  판례내용_이유        4178 non-null   object
# ...

# %%
df[['판례일련번호','사건번호','판례내용','판례내용_이유','판례내용_이유_불용어제거']]
# Out:
#       판례일련번호        사건번호                                               판례내용  \
# 0     241201   2021도1181  【피 고 인】 피고인【상 고 인】 검사【변 호 인】 법무법인 비엘에스 담당변호사 장...
# 1     241251   2020도7802  【피 고 인】 피고인【상 고 인】 피고인【변 호 인】 법무법인(유한) 바른 담당변호...
# 2     241189    2023노878  【피 고 인】 피고인【항 소 인】 피고인【검    사】 윤인식 외 1인【변 호 인】...
# 3     240943   2021도2340  【피 고 인】 피고인 1 외 1인【상 고 인】 피고인들【변 호 인】 변호사 이형주 ...
# 4     241423  2023고단2401  【피 고 인】 피고인【검    사】 박동준 외 2인【변 호 인】 법무법인 북부 담당...
# ...      ...         ...                                                ...
# 4177   86006    4287민상77  【원고, 상고인】   이기만【피고, 피상고인】   김학술【원심판결】 제1심 부산지방...
# 4178   86024   4287민상320  【원고, 피고인】   최영찬(소송대리인 변호사 최돈연)【피고, 상고인】   삼보세멘...
# 4179  215291   4286형상181  【상 고 인】   검사 김홍수【원    심】 서울지방법원【주    문】  본건 상고...
# 4180  215367   4286형상205  【상 고 인】   검사 장천수【원    심】 서울고등법원【주    문】  원판결을 ...
# 4181  232167    4282민공20  【원고, 피공소인】 원고【피고, 공소인】 피고 1 외 1인        【주    ...
#
# ...

# %%
df[df['판례일련번호']==203726]
# Out:
#      판례일련번호                   사건명        사건번호        선고일자       법원명 사건종류명  \
# 317  203726  전자금융거래법위반·사기방조·횡령·폭행  2017고단1882  2017.08.23  서울남부지방법원    형사
#
#                                                 판례상세링크  판례정보일련번호  선고 판결유형  \
# 317  /DRF/lawService.do?OC=wanja1996&target=prec&ID...    203726  선고   판결
#
#      ... 판결요지 참조조문 참조판례                                               판례내용  \
# 317  ...  NaN  NaN  NaN  【피 고 인】 【검    사】 김지혜, 오진희(기소), 이수진, 김한준(공판)【변 ...
#
#                                                판례내용_상단  \
# 317  【피 고 인】 【검    사】 김지혜, 오진희(기소), 이수진, 김한준(공판)【변 ...
#
#                                                판례내용_이유 판례내용_이유_전처리  \
# 317  【이    유】【범죄사실】『2017고단1882』1. 피고인 2의 범행피고인 2는 2...  {'이유': ''}
#
#                                          판례내용_이유_불용어제거 클러스터  \
# 317  】『 고단 순경 휴대전화 설치 카카오 어플 통해 성명 보이스피싱 직원 체크카드 보내...    6
#
#                                                    키워드
# 317  ['형법', '형사소송법', '징역', '판시', '사기죄', '상습', '사기',...
#
# ...
