# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# 글씨 깨짐방지

# %%
# 한글 깨짐 방지
plt.rcParams['font.family'] = "AppleGothic"

# 마이너스 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
df_Labor = pd.read_csv(r'C:\Users\user\Desktop\프로젝트 기획서\SeSac-2024\data_file\Labor_datacombied.csv')
df_Labor.head()
# Out:
#    판례일련번호                사건명        사건번호        선고일자     법원명 사건종류명  \
# 0  147393          소유권보존등기말소  2008다71575  2010.12.09     대법원    민사
# 1  147384            상속세경정청구  2008두10133  2010.12.09     대법원    세무
# 2  150031  횡령(인정된죄명:점유이탈물횡령)    2010도891  2010.12.09     대법원    형사
# 3  188185             통보처분취소  2010누12639  2010.12.08  서울고등법원  일반행정
# 4  160470              배당 이의  2010가합8730  2010.12.08  창원지방법원    민사
#
#                                               판례상세링크  선고  판결유형  \
# 0  /DRF/lawService.do?OC=ykdb0508&target=prec&ID=...  선고    판결
# 1  /DRF/lawService.do?OC=ykdb0508&target=prec&ID=...  선고    판결
# 2  /DRF/lawService.do?OC=ykdb0508&target=prec&ID=...  선고    판결
# 3  /DRF/lawService.do?OC=ykdb0508&target=prec&ID=...  선고    판결
# 4  /DRF/lawService.do?OC=ykdb0508&target=prec&ID=...  선고  일부판결
#
#                                                 판시사항  \
# 0  [1] 국가 또는 상위 지방자치단체가 법령의 규정 등에 의하여 그 권한의 일부를 하...
# 1  피상속인이 제3자를 위하여 연대보증채무를 부담하고 있었지만 상속개시 당시에는 아직 ...
# ...

# %%
df_Labor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22500 entries, 0 to 22499
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   판례일련번호     22500 non-null  int64
#  1   사건명        22497 non-null  object
#  2   사건번호       22500 non-null  object
#  3   선고일자       22500 non-null  object
#  4   법원명        22500 non-null  object
#  5   사건종류명      22499 non-null  object
#  6   판례상세링크     22500 non-null  object
#  7   선고         22500 non-null  object
#  8   판결유형       22500 non-null  object
#  9   판시사항       17175 non-null  object
#  10  판결요지       13095 non-null  object
#  11  참조조문       17169 non-null  object
#  12  참조판례       11687 non-null  object
#  13  판례내용       22500 non-null  object
#  14  판례내용_상단    22500 non-null  object
#  15  판례내용_이유    22493 non-null  object
#  16  재판당사자      22492 non-null  object
#  17  재판당사자_텍스트  22500 non-null  object
#  18  판례내용_이유2   22500 non-null  object
# ...

# %%
df_Labor.isnull().sum()
# Out:
# 판례일련번호           0
# 사건명              3
# 사건번호             0
# 선고일자             0
# 법원명              0
# 사건종류명            1
# 판례상세링크           0
# 선고               0
# 판결유형             0
# 판시사항          5325
# 판결요지          9405
# 참조조문          5331
# 참조판례         10813
# 판례내용             0
# 판례내용_상단          0
# 판례내용_이유          7
# 재판당사자            8
# 재판당사자_텍스트        0
# 판례내용_이유2         0
# dtype: int64

# %%
import pandas as pd

# 전처리 함수 정의
def preprocess_content(content):
    if pd.isna(content):  # NaN 값에 대한 예외 처리
        return content
    
    # content가 문자열인지 확인
    if isinstance(content, str):
        content = content.replace('<br/>', '')
        content = content.replace('\n', '')
        content = content.replace('\r', '')
    
    return content

# 여러 열에 전처리를 적용할 경우
columns_to_preprocess = ['참조조문','참조판례', '판례내용', '판례내용_상단', '판례내용_이유', '재판당사자']

# applymap이 아닌 각 열에 개별적으로 apply 사용
for col in columns_to_preprocess:
    df_Labor[col] = df_Labor[col].apply(preprocess_content)

# 전처리 후 데이터프레임 확인
df_Labor.head()

# %%
# 참조조문       17169 non-null  object
#  12  참조판례       11687 non-null  object
#  13  판례내용       22500 non-null  object
#  14  판례내용_상단    22500 non-null  object
#  15  판례내용_이유    22493 non-null  object
#  16  재판당사자      22492 non-null  object

import pandas as pd

# 전처리 함수 정의
def preprocess_content(content):
    if pd.isna(content):  # NaN 값에 대한 예외 처리
        return content
    
    # content가 문자열인지 확인
    if isinstance(content, str):
        content = content.replace('<br/>', '')
        content = content.replace('\n', '')
        content = content.replace('\r', '')
    
    return content

# 여러 열에 전처리를 적용할 경우
columns_to_preprocess = ['참조조문','참조판례', '판례내용', '판례내용_상단', '판례내용_이유', '재판당사자']

# applymap이 아닌 각 열에 개별적으로 apply 사용
for col in columns_to_preprocess:
    df_Labor[col] = df_Labor[col].apply(preprocess_content)

# 전처리 후 데이터프레임 확인
df_Labor.head()
# Out:
#    판례일련번호                사건명        사건번호        선고일자     법원명 사건종류명  \
# 0  147393          소유권보존등기말소  2008다71575  2010.12.09     대법원    민사
# 1  147384            상속세경정청구  2008두10133  2010.12.09     대법원    세무
# 2  150031  횡령(인정된죄명:점유이탈물횡령)    2010도891  2010.12.09     대법원    형사
# 3  188185             통보처분취소  2010누12639  2010.12.08  서울고등법원  일반행정
# 4  160470              배당 이의  2010가합8730  2010.12.08  창원지방법원    민사
#
#                                               판례상세링크  선고  판결유형  \
# 0  /DRF/lawService.do?OC=ykdb0508&target=prec&ID=...  선고    판결
# 1  /DRF/lawService.do?OC=ykdb0508&target=prec&ID=...  선고    판결
# 2  /DRF/lawService.do?OC=ykdb0508&target=prec&ID=...  선고    판결
# 3  /DRF/lawService.do?OC=ykdb0508&target=prec&ID=...  선고    판결
# 4  /DRF/lawService.do?OC=ykdb0508&target=prec&ID=...  선고  일부판결
#
#                                                 판시사항  \
# 0  [1] 국가 또는 상위 지방자치단체가 법령의 규정 등에 의하여 그 권한의 일부를 하...
# 1  피상속인이 제3자를 위하여 연대보증채무를 부담하고 있었지만 상속개시 당시에는 아직 ...
# ...

# %%
df_Labor.to_csv('Labor_datacombined.csv', index=False)

# %% [markdown]
# 빈도수 계산

# %%
import pandas as pd
from collections import Counter
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer

# %%
ax = df_Labor['판결요지'].str.len().hist()

ax.set_xlabel('글자 수')
ax.set_ylabel('빈도 수')

# %%
# 판례내용

# # 판례 데이터를 불러옴 (예시로 DataFrame 사용)
# data = pd.read_csv("cases.csv")  # 판례 데이터를 불러온다고 가정
# documents = data['content']  # 판례 내용이 담긴 열

# # 한글 형태소 분석기 사용 (Okt)
# okt = Okt()

# # 모든 판례에서 명사만 추출
# nouns = []
# for doc in documents:
#     nouns.extend(okt.nouns(doc))

# # 빈도 분석
# word_freq = Counter(nouns)
# most_common_words = word_freq.most_common(20)  # 가장 많이 등장한 20개 단어

# print(most_common_words)


okt = Okt()

nouns = []
for doc in df_Labor['판례내용'] :
    nouns.extend(okt.nouns(doc))

word_freq = Counter(nouns)
most_common_words = word_freq.most_common(50)
print(most_common_words)
# Out:
# [('제', 491926), ('이', 473405), ('위', 357826), ('사건', 338180), ('것', 327074), ('원고', 317022), ('그', 287661), ('피고', 282133), ('소외', 236877), ('등', 236853), ('수', 201709), ('피고인', 194326), ('및', 174755), ('판결', 170836), ('사실', 167203), ('관', 160216), ('이유', 145057), ('대한', 137846), ('각', 130870), ('원심', 126926), ('의', 116675), ('항', 114062), ('인정', 111646), ('대하', 110332), ('경우', 103834), ('점', 103560), ('주장', 97463), ('상고', 97339), ('규정', 95956), ('판단', 95625), ('중', 84342), ('부분', 79702), ('회사', 78669), ('지급', 74886), ('기재', 74740), ('법', 74618), ('행위', 74314), ('선고', 73748), ('계약', 70738), ('주식회사', 70385), ('사업', 66035), ('원', 62280), ('금', 62199), ('해당', 62051), ('청구', 61660), ('바', 61150), ('함', 60142), ('호증', 57308), ('후', 56400), ('토지', 56363)]

# %%
most_common_words_list = [
    ('제', 491926), ('이', 473405), ('위', 357826), ('사건', 338180), ('것', 327074),
    ('원고', 317022), ('그', 287661), ('피고', 282133), ('소외', 236877), ('등', 236853),
    ('수', 201709), ('피고인', 194326), ('및', 174755), ('판결', 170836), ('사실', 167203),
    ('관', 160216), ('이유', 145057), ('대한', 137846), ('각', 130870), ('원심', 126926),
    ('의', 116675), ('항', 114062), ('인정', 111646), ('대하', 110332), ('경우', 103834),
    ('점', 103560), ('주장', 97463), ('상고', 97339), ('규정', 95956), ('판단', 95625),
    ('중', 84342), ('부분', 79702), ('회사', 78669), ('지급', 74886), ('기재', 74740),
    ('법', 74618), ('행위', 74314), ('선고', 73748), ('계약', 70738), ('주식회사', 70385),
    ('사업', 66035), ('원', 62280), ('금', 62199), ('해당', 62051), ('청구', 61660),
    ('바', 61150), ('함', 60142), ('호증', 57308), ('후', 56400), ('토지', 56363)
]
print(most_common_words_list)
# Out:
# [('제', 491926), ('이', 473405), ('위', 357826), ('사건', 338180), ('것', 327074), ('원고', 317022), ('그', 287661), ('피고', 282133), ('소외', 236877), ('등', 236853), ('수', 201709), ('피고인', 194326), ('및', 174755), ('판결', 170836), ('사실', 167203), ('관', 160216), ('이유', 145057), ('대한', 137846), ('각', 130870), ('원심', 126926), ('의', 116675), ('항', 114062), ('인정', 111646), ('대하', 110332), ('경우', 103834), ('점', 103560), ('주장', 97463), ('상고', 97339), ('규정', 95956), ('판단', 95625), ('중', 84342), ('부분', 79702), ('회사', 78669), ('지급', 74886), ('기재', 74740), ('법', 74618), ('행위', 74314), ('선고', 73748), ('계약', 70738), ('주식회사', 70385), ('사업', 66035), ('원', 62280), ('금', 62199), ('해당', 62051), ('청구', 61660), ('바', 61150), ('함', 60142), ('호증', 57308), ('후', 56400), ('토지', 56363)]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 한글 폰트 경로 지정 (NanumGothic 폰트를 사용한 경우)
font_path = 'C:/Users/user/Downloads/NanumGothic.ttf'  # 폰트 파일 경로 수정

# 상위 50개의 단어를 사용한 워드 클라우드 생성
wordcloud = WordCloud(font_path=font_path,  # 한글 폰트 경로 설정
                      width=800, height=400, background_color='white').generate_from_frequencies(dict(most_common_words_list))

# 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # 축 숨기기
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# most_common_words의 내용을 단어와 빈도로 분리
words, counts = zip(*most_common_words)

# 시각화 (막대 그래프)
plt.figure(figsize=(10, 8))
sns.barplot(x=counts, y=words, palette='viridis', hue=words, dodge=False, legend=False)  # hue로 y 변수 할당
plt.title('Top 50 Most Common Words')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.show()

# %%
# 형태소 분석을 통해 명사뿐만 아니라 동사, 형용사도 포함하여 분석
tokens = []
for doc in df_Labor['판례내용'].iloc[:100]:
    # 문서에서 형태소 분석
    tokens.extend(okt.pos(doc, norm=True, stem=True))  # norm: 정규화, stem: 어간 추출

# 특정 품사만 선택 (명사, 동사, 형용사)
meaningful_tokens = [word for word, pos in tokens if pos in ['Noun', 'Verb', 'Adjective']]

# 빈도 계산
word_freq2 = Counter(meaningful_tokens)

# 상위 50개 의미 단어 출력
most_common_words2 = word_freq2.most_common(50)
print(most_common_words2)
# Out:
# [('하다', 10429), ('이', 3272), ('있다', 2522), ('원고', 2469), ('사건', 2383), ('되다', 2142), ('제', 2029), ('피고', 1878), ('위', 1775), ('것', 1592), ('그', 1483), ('계약', 1372), ('소외', 1347), ('등', 1331), ('각', 1195), ('없다', 1159), ('및', 1124), ('수', 1106), ('사실', 912), ('피고인', 895), ('관', 891), ('환율', 862), ('되어다', 761), ('판결', 752), ('같다', 737), ('대한', 718), ('아니다', 696), ('경우', 691), ('점', 689), ('통화', 655), ('의하다', 648), ('따르다', 636), ('이유', 629), ('인정', 604), ('이르다', 584), ('옵션', 584), ('의', 579), ('판단', 573), ('주식회사', 570), ('주장', 546), ('받다', 527), ('않다', 519), ('대하', 503), ('옵션계약', 492), ('체결', 491), ('원심', 488), ('지급', 461), ('부분', 458), ('위험', 442), ('기재', 436)]

# %%
# 판례 100개

import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# most_common_words의 내용을 단어와 빈도로 분리
words, counts = zip(*most_common_words2)

# 시각화 (막대 그래프)
plt.figure(figsize=(10, 8))
sns.barplot(x=counts, y=words, palette='viridis', hue=words, dodge=False, legend=False)  # hue로 y 변수 할당
plt.title('Top 50 Most Common Words')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.show()

# %%
## 판례 20개

import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# most_common_words의 내용을 단어와 빈도로 분리
words, counts = zip(*most_common_words2)

# 시각화 (막대 그래프)
plt.figure(figsize=(10, 8))
sns.barplot(x=counts, y=words, palette='viridis', hue=words, dodge=False, legend=False)  # hue로 y 변수 할당
plt.title('Top 50 Most Common Words')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.show()

# %% [markdown]
# 불용어 사전

# %%
# 불용어 사전 파일 경로
stopwords_file_path = r'C:\Users\user\Desktop\프로젝트 기획서\SeSac-2024\EDA_Ref_code\sorted_words.txt'

# 불용어 리스트 초기화
stopwords = []

# 불용어 사전 파일 읽기
with open(stopwords_file_path, 'r', encoding='utf-8') as file:
    stopwords = [line.strip() for line in file.readlines()]  # 각 줄에서 줄바꿈 문자 제거

# 불용어 리스트 출력
print("불용어 리스트:", stopwords)
# Out:
# 불용어 리스트: ['#', 'adverbs', 'conjunctions', 'connective_words', 'exclamations', 'meaningless_words', 'numbers', 'onomatopoeia', 'particles', 'past_tense_verbs', 'precedents', 'pronouns', 'verb_endings', '가', '가까스로', '가끔', '가다', '가령', '가서', '가장', '가졌다', '각', '각각', '각자', '각종', '갔다', '갖고말하자면', '같다', '같은', '같이', '개의치않고', '거나', '거니와', '거바', '거의', '것', '것과', '것들', '게다가', '게우다', '겨우', '견지에서', '결과에', '결과적으로', '결국', '결론을', '결론적으로', '겸사겸사', '고려하다', '고려하면', '고로', '곧', '공동으로', '공식적으로', '과', '과연', '관계가', '관계없이', '관련이', '관련하여', '관하여', '관한', '관해서는', '굉장히', '구', '구체적으로', '구토하다', '규정된', '규정하다', '그', '그것', '그녀', '그녀들', '그대', '그들', '그때', '그래', '그래도', '그래서', '그러나', '그러니', '그러니까', '그러면', '그러므로', '그러한즉', '그런', '그런데', '그런즉', '그럼', '그럼에도', '그렇게', '그렇기', '그렇지', '그렇지만', '그렇지않으면', '그리고', '그리하여', '그만이다', '그분', '그야말로', '그에', '그와', '그위에', '그저', '그중에서', '그치지', '근거로', '근거하여', '기다렸다', '기대여', '기억하다', '기억했다', '기점으로', '기준으로', '기타', '김에', '까닭에', '까닭으로', '까악', '까지', '까지도', '께', '께서', '꼬르륵', '꽈당', '끙끙', '끝으로', '끼익', '나', '나
# ...

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# %%
df_Labor = pd.read_csv(r'C:\Users\user\Desktop\프로젝트 기획서\SeSac-2024\data_file\Labor_datacombied.csv')
df_Labor.head()

# %%
stopwords_file_path = r'C:\Users\user\Desktop\프로젝트 기획서\SeSac-2024\data_file\sorted_words.txt'

stopwords = []
with open(stopwords_file_path, 'r', encoding='utf-8') as file:
    stopwords = [line.strip() for line in file.readlines()]

# %%
from konlpy.tag import Okt

okt = Okt()
tokenized_docs = []

for doc in df_Labor['판례내용'].iloc[:200]:
    tokens = okt.nouns(doc)
    filtered_tokens = [word for word in tokens if word not in stopwords]
    tokenized_docs.append(' '.join(filtered_tokens))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from konlpy.tag import Okt
#       3 okt = Okt()
#       4 tokenized_docs = []
#
# File c:\Users\user\anaconda3\envs\sesacnof\Lib\site-packages\konlpy\__init__.py:12
#       9     pass
#      11 from konlpy.jvm import init_jvm
# ---> 12 from konlpy import (
#      13     corpus,
#      14     data,
#      15     internals,
#      16     tag
#      17 )
#
# File c:\Users\user\anaconda3\envs\sesacnof\Lib\site-packages\konlpy\tag\__init__.py:6
#       3 import sys
#       4 import warnings
# ----> 6 from konlpy.tag._hannanum import Hannanum
#       7 from konlpy.tag._kkma import Kkma
#       8 from konlpy.tag._komoran import Komoran
#
# File c:\Users\user\anaconda3\envs\sesacnof\Lib\site-packages\konlpy\tag\_hannanum.py:7
#       3 from __future__ import unicode_literals
#       5 import re
# ...

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(tokenized_docs)

num_topics = 5
lda = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda.fit(X)

for idx, topic in enumerate(lda.components_):
    print(f"Topic {idx}:")
    top_features_ind = topic.argsort()[-10:][::-1]
    top_features = [vectorizer.get_feature_names_out()[i] for i in top_features_ind]
    print(" ".join(top_features))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 okt = Okt()
#       2 tokenized_docs = []
#       4 for doc in df_Labor['판례내용'].iloc[:200]:
#
# NameError: name 'Okt' is not defined

# %%
# LDA를 위한 단어-문서 매트릭스 생성
dictionary = corpora.Dictionary(tokenized_docs)
corpus = [dictionary.doc2bow(doc) for doc in tokenized_docs]

# LDA 모델 훈련
num_topics = 3  # 원하는 주제 수
lda_model = LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=15)

# 주제어 출력
for idx, topic in lda_model.print_topics(-1):
    print(f"Topic {idx}: {topic}")

# %%
# LDA 모델 학습
lda_model = LdaModel(corpus, num_topics=3, id2word=dictionary, passes=10)

# 각 주제 출력
for idx, topic in lda_model.print_topics(-1):
    print(f"Topic {idx}: {topic}")
# Out:
# Topic 0: 0.023*"원고" + 0.021*"제" + 0.020*"피고" + 0.018*"사건" + 0.013*"위" + 0.010*"것" + 0.009*"및" + 0.009*"관" + 0.009*"소외" + 0.009*"등"
# Topic 1: 0.020*"원고" + 0.020*"계약" + 0.016*"사건" + 0.016*"환율" + 0.014*"각" + 0.013*"피고" + 0.013*"것" + 0.012*"위" + 0.012*"소외" + 0.012*"통화"
# Topic 2: 0.021*"사건" + 0.019*"제" + 0.015*"위" + 0.013*"것" + 0.012*"피고인" + 0.012*"사실" + 0.011*"등" + 0.011*"원고" + 0.010*"판결" + 0.009*"소외"

# %%
import matplotlib.pyplot as plt

# 주제별 상위 단어 시각화
def plot_top_words(model, feature_names, n_top_words):
    fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True)
    for i, ax in enumerate(axes):
        top_words = model.show_topic(i, n_top_words)
        words, weights = zip(*top_words)
        ax.barh(words, weights, align='center')
        ax.set_title(f'Topic {i+1}', fontsize=16)
        ax.invert_yaxis()  # 상위 단어가 위에 오도록
    plt.tight_layout()
    plt.show()

# 상위 단어 개수 설정
n_top_words = 10
plot_top_words(lda_model, dictionary.token2id, n_top_words)

# %%
import pandas as pd
from nltk.corpus import stopwords
from konlpy.tag import Okt

# 예시 데이터 로드
# df_Labor = pd.read_csv('your_data.csv')  # 데이터 파일 경로를 입력하세요.

# 한국어 불용어 리스트 가져오기
stop_words = set(stopwords.words('korean'))

# 텍스트 전처리 함수
def preprocess_text(text):
    okt = Okt()
    # 명사 추출
    tokens = okt.nouns(text)
    # 불용어 제거
    tokens = [word for word in tokens if word not in stop_words]
    return tokens

# '판례내용' 열에 대해 전처리
df_Labor['processed'] = df_Labor['판례내용'].iloc[:100].apply(preprocess_text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from nltk.corpus import stopwords
#       3 from konlpy.tag import Okt
#       5 # 예시 데이터 로드
#       6 # df_Labor = pd.read_csv('your_data.csv')  # 데이터 파일 경로를 입력하세요.
#       7
#       8 # 한국어 불용어 리스트 가져오기
#
# File c:\Users\user\anaconda3\envs\sesacnof\Lib\site-packages\nltk\__init__.py:138
#     136 from nltk.grammar import *
#     137 from nltk.probability import *
# --> 138 from nltk.text import *
#     139 from nltk.util import *
#     140 from nltk.jsontags import *
#
# File c:\Users\user\anaconda3\envs\sesacnof\Lib\site-packages\nltk\text.py:30
#      28 from nltk.probability import ConditionalFreqDist as CFD
#      29 from nltk.probability import FreqDist
# ---> 30 from nltk.tokenize import sent_tokenize
# ...
