# %%
import pandas as pd
df = pd.read_csv('data/df_data.csv')
df
# Out:
#        판례일련번호                               사건명     사건번호        선고일자     법원명  \
# 0      116601                           도시계획법위반   98도364  1998.04.14     대법원
# 1      116564                              물품대금  98다6565  1998.04.14     대법원
# 2      196350                              수표금등  96다8826  1998.04.14     대법원
# 3      116597                                무고   98도150  1998.04.14     대법원
# 4      116598                                사기   98도231  1998.04.14     대법원
# ...       ...                               ...      ...         ...     ...
# 22495  100987                              특수절도  85도1146  1985.10.08     대법원
# 22496  100978                         소득세부과처분취소   85누529  1985.10.08     대법원
# 22497  100995  특수강도,특수절도,폭력행위등처벌에관한법률위반,도로교통법위반  85도1721  1985.10.08     대법원
# 22498  205858                     등기공무원의결정에대한이의   85마410  1985.10.04     대법원
# 22499   76371                   부가가치세부과처분취소청구사건  84구1046  1985.10.02  서울고등법원
#
# ...

# %%
df['사건종류명'].value_counts()
# Out:
# 사건종류명
# 민사      9758
# 형사      4252
# 세무      3554
# 일반행정    3331
# 특허      1164
# 가사       440
# Name: count, dtype: int64

# %%
df['사건명'].value_counts()
# Out:
# 사건명
# 손해배상(기)                             887
# 소유권이전등기                             723
# 손해배상(자)                             655
# 거절사정                                524
# 양도소득세등부과처분취소                        478
#                                    ...
# 항소 기각 결정에 대한 재항고                      1
# 전기통신공사업허가취소처분취소                       1
# 국가보안법,간첩방조                            1
# 부동산가처분취소                              1
# 특수강도,특수절도,폭력행위등처벌에관한법률위반,도로교통법위반      1
# Name: count, Length: 5810, dtype: int64
